# %% [markdown]
# <p>Створення Обробка та аналіз біомедичних даних</p>

# %% [markdown]
# <p>БС-82</p>

# %% [markdown]
# <p>Мусієнко</p>

# %%
import pandas as pd

# %%
new_df=pd.DataFrame(
{
    "Model": ['X', 'XR', 'XS'],
    "ROM": [256, 512, 64],
    "Camera": [12, 16, 16],
    "Color": ['Jet Black', 'Space Grey', 'Gold'],
    "Dual SIM": [False, False, False],
    "Size": [5.8, 6.1, 5.8]
})

new_df
# Out:
#   Model  ROM  Camera       Color  Dual SIM  Size
# 0     X  256      12   Jet Black     False   5.8
# 1    XR  512      16  Space Grey     False   6.1
# 2    XS   64      16        Gold     False   5.8

# %%
path="C:/database.csv"
data=pd.read_csv(path, encoding='utf-8')

print(type(data))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
import os

print("The directory we are working in is: {}".format(os.getcwd()))
# Out:
# The directory we are working in is: C:\Users\vigor\dasha

# %%
data = pd.read_csv('database.csv')

print(type(data))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
data
# Out:
#    Flight Number        Launch Date Launch Time                  Launch Site  \
# 0           F1-1      24 March 2006       22:30             Marshall Islands
# 1           F1-2      21 March 2007       01:10             Marshall Islands
# 2           F1-3      3 August 2008       03:34             Marshall Islands
# 3           F1-3      3 August 2008       03:34             Marshall Islands
# 4           F1-3      3 August 2008       03:34             Marshall Islands
# 5           F1-4  28 September 2008       23:15             Marshall Islands
# 6           F1-5       14 July 2009       03:35             Marshall Islands
# 7           F9-1        4 June 2010       18:45     Cape Canaveral AFS LC-40
# 8           F9-2    8 December 2010       15:43     Cape Canaveral AFS LC-40
# 9           F9-3        22 May 2012       07:44     Cape Canaveral AFS LC-40
# 10          F9-4     8 October 2012       00:35     Cape Canaveral AFS LC-40
# ...

# %%
data.shape
# Out:
# (41, 16)

# %%
data.head(5)
# Out:
#   Flight Number    Launch Date Launch Time       Launch Site Vehicle Type  \
# 0          F1-1  24 March 2006       22:30  Marshall Islands     Falcon 1
# 1          F1-2  21 March 2007       01:10  Marshall Islands     Falcon 1
# 2          F1-3  3 August 2008       03:34  Marshall Islands     Falcon 1
# 3          F1-3  3 August 2008       03:34  Marshall Islands     Falcon 1
# 4          F1-3  3 August 2008       03:34  Marshall Islands     Falcon 1
#
#          Payload Name             Payload Type  Payload Mass (kg)  \
# 0         FalconSAT-2       Research Satellite               19.5
# 1             DemoSat                      NaN                NaN
# 2         Trailblazer  Communication Satellite                NaN
# 3  PRESat, NanoSail-D      Research Satellites                8.0
# 4           Explorers            Human Remains                NaN
#
#   Payload Orbit Customer Name Customer Type Customer Country Mission Outcome  \
# ...

# %%
data.tail(5)
# Out:
#    Flight Number       Launch Date Launch Time                  Launch Site  \
# 36          FT-7      18 July 2016       04:45     Cape Canaveral AFS LC-40
# 37          FT-8    14 August 2016       05:26     Cape Canaveral AFS LC-40
# 38          FT-9  1 September 2016       13:07     Cape Canaveral AFS LC-40
# 39         FT-10   14 January 2017       17:54        Vandenberg AFB SLC-4E
# 40         FT-11  19 February 2017       14:39  Kennedy Space Center LC-39A
#
#                    Vehicle Type       Payload Name             Payload Type  \
# 36  Falcon 9 Full Thrust (v1.2)       SpaceX CRS-9   Space Station Supplies
# 37  Falcon 9 Full Thrust (v1.2)           JCSAT-16  Communication Satellite
# 38  Falcon 9 Full Thrust (v1.2)             Amos-6  Communication Satellite
# 39  Falcon 9 Full Thrust (v1.2)  Iridium NEXT 1-10  Communication Satellite
# 40  Falcon 9 Full Thrust (v1.2)      SpaceX CRS-10   Space Station Supplies
#
# ...

# %%
data.dtypes
# Out:
# Flight Number         object
# Launch Date           object
# Launch Time           object
# Launch Site           object
# Vehicle Type          object
# Payload Name          object
# Payload Type          object
# Payload Mass (kg)    float64
# Payload Orbit         object
# Customer Name         object
# Customer Type         object
# Customer Country      object
# Mission Outcome       object
# Failure Reason        object
# Landing Type          object
# Landing Outcome       object
# dtype: object

# %%
data.describe()
# Out:
#        Payload Mass (kg)
# count          33.000000
# mean         2739.772727
# std          2131.502973
# min             8.000000
# 25%           570.000000
# 50%          2490.000000
# 75%          4159.000000
# max          9600.000000

# %%
data['Payload Type'].describe()
# Out:
# count                          38
# unique                          7
# top       Communication Satellite
# freq                           19
# Name: Payload Type, dtype: object

# %%
data['Launch Date'].describe()
# Out:
# count                41
# unique               36
# top       3 August 2008
# freq                  3
# Name: Launch Date, dtype: object

# %%
cut_data=data.iloc[0:10, :]

cut_data
# Out:
#   Flight Number        Launch Date Launch Time               Launch Site  \
# 0          F1-1      24 March 2006       22:30          Marshall Islands
# 1          F1-2      21 March 2007       01:10          Marshall Islands
# 2          F1-3      3 August 2008       03:34          Marshall Islands
# 3          F1-3      3 August 2008       03:34          Marshall Islands
# 4          F1-3      3 August 2008       03:34          Marshall Islands
# 5          F1-4  28 September 2008       23:15          Marshall Islands
# 6          F1-5       14 July 2009       03:35          Marshall Islands
# 7          F9-1        4 June 2010       18:45  Cape Canaveral AFS LC-40
# 8          F9-2    8 December 2010       15:43  Cape Canaveral AFS LC-40
# 9          F9-3        22 May 2012       07:44  Cape Canaveral AFS LC-40
#
#       Vehicle Type                          Payload Name  \
# 0         Falcon 1                           FalconSAT-2
# ...

# %%
new_data= ["before 2010", "before 2010", "before 2010", "before 2010", "before 2010", "before 2010", "before 2010", "after 2010", "after 2010", "after 2010" ]
cut_data.insert(1, "Date", new_data)
cut_data
# Out:
#   Flight Number         Date        Launch Date Launch Time  \
# 0          F1-1  before 2010      24 March 2006       22:30
# 1          F1-2  before 2010      21 March 2007       01:10
# 2          F1-3  before 2010      3 August 2008       03:34
# 3          F1-3  before 2010      3 August 2008       03:34
# 4          F1-3  before 2010      3 August 2008       03:34
# 5          F1-4  before 2010  28 September 2008       23:15
# 6          F1-5  before 2010       14 July 2009       03:35
# 7          F9-1   after 2010        4 June 2010       18:45
# 8          F9-2   after 2010    8 December 2010       15:43
# 9          F9-3   after 2010        22 May 2012       07:44
#
#                 Launch Site     Vehicle Type  \
# 0          Marshall Islands         Falcon 1
# 1          Marshall Islands         Falcon 1
# 2          Marshall Islands         Falcon 1
# 3          Marshall Islands         Falcon 1
# 4          Marshall Islands         Falcon 1
# ...

# %%
cut_data.groupby('Date').describe()
# Out:
#             Payload Mass (kg)                                                 \
#                         count    mean        std  min     25%    50%     75%
# Date
# after 2010                0.0     NaN        NaN  NaN     NaN    NaN     NaN
# before 2010               4.0  93.125  91.978598  8.0  16.625  92.25  168.75
#
#
#                max
# Date
# after 2010     NaN
# before 2010  180.0

# %%
cut_data.to_csv("output.csv", encoding='utf8')
